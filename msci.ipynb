# %% [markdown]
# # MSCI Indonesian Stocks
# A Python script to monitor MSCI stocks performance by comparing the current market price against predefined base and support levels.

# %%
import yfinance as yf
import pandas as pd

# %%
def analyze_stocks(list_A, base_A, support_A):
    # Download last closing prices
    data = yf.download(list_A, period="1d", progress=False)
    closing = data['Close'].iloc[-1]

    # Ensure correct order of closing prices
    last_A = [closing[ticker] for ticker in list_A]

    # Create DataFrame
    stocks_A = pd.DataFrame({
        'Stock': list_A,
        'Base': base_A,
        'Support': support_A,
        'Last Price': last_A})
    
    stocks_A['Change from Base (%)'] = (stocks_A['Last Price'] - stocks_A['Base'])/stocks_A['Base']*100
    stocks_A['Change from Support (%)'] = (stocks_A['Last Price'] - stocks_A['Support'])/stocks_A['Support']*100

    # Styling function
    def color_change(val):
        color = 'green' if val > 0 else 'red'
        return f'color: {color}'

    # Return styled DataFrame
    styled_stocks_A = stocks_A.style \
        .map(color_change, subset=['Change from Base (%)', 'Change from Support (%)']) \
        .format({
            'Last Price': '{:.0f}',
            'Change from Base (%)': '{:.2f}',
            'Change from Support (%)': '{:.2f}'})
    return styled_stocks_A

# %%
def analyze_stocks_realtime(list_A, base_A, support_A):
    # Get realtime prices using .fast_info['lastPrice']
    last_A = []
    for ticker in list_A:
        try:
            stock = yf.Ticker(ticker)
            last_price = stock.fast_info['lastPrice']
        except Exception:
            last_price = None
        last_A.append(last_price)

    # Create DataFrame
    stocks_A = pd.DataFrame({
        'Stock': list_A,
        'Base': base_A,
        'Support': support_A,
        'Last': last_A})

    # Create DataFrame
    stocks_A = pd.DataFrame({
        'Stock': list_A,
        'Base': base_A,
        'Support': support_A,
        'Last Price': last_A})
    
    stocks_A['Change from Base (%)'] = (stocks_A['Last Price'] - stocks_A['Base'])/stocks_A['Base']*100
    stocks_A['Change from Support (%)'] = (stocks_A['Last Price'] - stocks_A['Support'])/stocks_A['Support']*100

    # Styling function
    def color_change(val):
        color = 'green' if val > 0 else 'red'
        return f'color: {color}'

    # Return styled DataFrame
    styled_stocks_A = stocks_A.style \
        .map(color_change, subset=['Change from Base (%)', 'Change from Support (%)']) \
        .format({
            'Last Price': '{:.0f}',
            'Change from Base (%)': '{:.2f}',
            'Change from Support (%)': '{:.2f}'})
    return styled_stocks_A

# %% [markdown]
# ## Watchlist A: Longterm Investment

# %%
# MSCI Global Standard
list_A = ["BBCA.JK", "BBRI.JK", "BMRI.JK", "BBNI.JK", "TLKM.JK", "ASII.JK", "AMMN.JK", "AMRT.JK", "GOTO.JK", "TPIA.JK", "CPIN.JK", "INDF.JK", "KLBF.JK", "ICBP.JK", "BRPT.JK", "UNTR.JK", "CUAN.JK", "DSSA.JK"]
base_A = [7400, 3360, 4350, 3670, 2310, 4430, 4590, 1775, 50, 2010, 4070, 5875, 1025, 9350, 600, 20075, 472, 30550]
support_A = [8200, 3650, 4510, 3950, 2630, 4690, 7225, 2160, 58, 6325, 4070, 6600, 1025, 9350, 2180, 20900, 1180, 52800]

stocks_A = analyze_stocks(list_A, base_A, support_A)
stocks_A
# Out:
# /var/folders/h9/3814k15d6g9gqm3g5762t5g40000gn/T/ipykernel_8216/49570061.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(list_A, period="1d", progress=False)
# <style type="text/css">
# #T_d5ece_row0_col4, #T_d5ece_row0_col5, #T_d5ece_row1_col4, #T_d5ece_row1_col5, #T_d5ece_row2_col4, #T_d5ece_row2_col5, #T_d5ece_row3_col4, #T_d5ece_row3_col5, #T_d5ece_row4_col4, #T_d5ece_row4_col5, #T_d5ece_row5_col4, #T_d5ece_row5_col5, #T_d5ece_row6_col4, #T_d5ece_row6_col5, #T_d5ece_row7_col4, #T_d5ece_row7_col5, #T_d5ece_row8_col4, #T_d5ece_row8_col5, #T_d5ece_row9_col4, #T_d5ece_row9_col5, #T_d5ece_row10_col4, #T_d5ece_row10_col5, #T_d5ece_row11_col4, #T_d5ece_row11_col5, #T_d5ece_row12_col4, #T_d5ece_row12_col5, #T_d5ece_row14_col4, #T_d5ece_row14_col5, #T_d5ece_row15_col4, #T_d5ece_row15_col5, #T_d5ece_row16_col4, #T_d5ece_row16_col5, #T_d5ece_row17_col4, #T_d5ece_row17_col5 {
#   color: green;
# }
# #T_d5ece_row13_col4, #T_d5ece_row13_col5 {
#   color: red;
# }
# </style>
# <table id="T_d5ece">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5ece_level0_col0" class="col_heading level0 col0" >Stock</th>
#       <th id="T_d5ece_level0_col1" class="col_heading level0 col1" >Base</th>
#       <th id="T_d5ece_level0_col2" class="col_heading level0 col2" >Support</th>
#       <th id="T_d5ece_level0_col3" class="col_heading level0 col3" >Last Price</th>
#       <th id="T_d5ece_level0_col4" class="col_heading level0 col4" >Change from Base (%)</th>
#       <th id="T_d5ece_level0_col5" class="col_heading level0 col5" >Change from Support (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5ece_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5ece_row0_col0" class="data row0 col0" >BBCA.JK</td>
#       <td id="T_d5ece_row0_col1" class="data row0 col1" >7400</td>
#       <td id="T_d5ece_row0_col2" class="data row0 col2" >8200</td>
#       <td id="T_d5ece_row0_col3" class="data row0 col3" >8300</td>
#       <td id="T_d5ece_row0_col4" class="data row0 col4" >12.16</td>
#       <td id="T_d5ece_row0_col5" class="data row0 col5" >1.22</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5ece_row1_col0" class="data row1 col0" >BBRI.JK</td>
#       <td id="T_d5ece_row1_col1" class="data row1 col1" >3360</td>
#       <td id="T_d5ece_row1_col2" class="data row1 col2" >3650</td>
#       <td id="T_d5ece_row1_col3" class="data row1 col3" >3700</td>
#       <td id="T_d5ece_row1_col4" class="data row1 col4" >10.12</td>
#       <td id="T_d5ece_row1_col5" class="data row1 col5" >1.37</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5ece_row2_col0" class="data row2 col0" >BMRI.JK</td>
#       <td id="T_d5ece_row2_col1" class="data row2 col1" >4350</td>
#       <td id="T_d5ece_row2_col2" class="data row2 col2" >4510</td>
#       <td id="T_d5ece_row2_col3" class="data row2 col3" >4670</td>
#       <td id="T_d5ece_row2_col4" class="data row2 col4" >7.36</td>
#       <td id="T_d5ece_row2_col5" class="data row2 col5" >3.55</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5ece_row3_col0" class="data row3 col0" >BBNI.JK</td>
#       <td id="T_d5ece_row3_col1" class="data row3 col1" >3670</td>
#       <td id="T_d5ece_row3_col2" class="data row3 col2" >3950</td>
#       <td id="T_d5ece_row3_col3" class="data row3 col3" >4070</td>
#       <td id="T_d5ece_row3_col4" class="data row3 col4" >10.90</td>
#       <td id="T_d5ece_row3_col5" class="data row3 col5" >3.04</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5ece_row4_col0" class="data row4 col0" >TLKM.JK</td>
#       <td id="T_d5ece_row4_col1" class="data row4 col1" >2310</td>
#       <td id="T_d5ece_row4_col2" class="data row4 col2" >2630</td>
#       <td id="T_d5ece_row4_col3" class="data row4 col3" >2940</td>
#       <td id="T_d5ece_row4_col4" class="data row4 col4" >27.27</td>
#       <td id="T_d5ece_row4_col5" class="data row4 col5" >11.79</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d5ece_row5_col0" class="data row5 col0" >ASII.JK</td>
#       <td id="T_d5ece_row5_col1" class="data row5 col1" >4430</td>
#       <td id="T_d5ece_row5_col2" class="data row5 col2" >4690</td>
#       <td id="T_d5ece_row5_col3" class="data row5 col3" >4920</td>
#       <td id="T_d5ece_row5_col4" class="data row5 col4" >11.06</td>
#       <td id="T_d5ece_row5_col5" class="data row5 col5" >4.90</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d5ece_row6_col0" class="data row6 col0" >AMMN.JK</td>
#       <td id="T_d5ece_row6_col1" class="data row6 col1" >4590</td>
#       <td id="T_d5ece_row6_col2" class="data row6 col2" >7225</td>
#       <td id="T_d5ece_row6_col3" class="data row6 col3" >8700</td>
#       <td id="T_d5ece_row6_col4" class="data row6 col4" >89.54</td>
#       <td id="T_d5ece_row6_col5" class="data row6 col5" >20.42</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d5ece_row7_col0" class="data row7 col0" >AMRT.JK</td>
#       <td id="T_d5ece_row7_col1" class="data row7 col1" >1775</td>
#       <td id="T_d5ece_row7_col2" class="data row7 col2" >2160</td>
#       <td id="T_d5ece_row7_col3" class="data row7 col3" >2350</td>
#       <td id="T_d5ece_row7_col4" class="data row7 col4" >32.39</td>
#       <td id="T_d5ece_row7_col5" class="data row7 col5" >8.80</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d5ece_row8_col0" class="data row8 col0" >GOTO.JK</td>
#       <td id="T_d5ece_row8_col1" class="data row8 col1" >50</td>
#       <td id="T_d5ece_row8_col2" class="data row8 col2" >58</td>
#       <td id="T_d5ece_row8_col3" class="data row8 col3" >62</td>
#       <td id="T_d5ece_row8_col4" class="data row8 col4" >24.00</td>
#       <td id="T_d5ece_row8_col5" class="data row8 col5" >6.90</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d5ece_row9_col0" class="data row9 col0" >TPIA.JK</td>
#       <td id="T_d5ece_row9_col1" class="data row9 col1" >2010</td>
#       <td id="T_d5ece_row9_col2" class="data row9 col2" >6325</td>
#       <td id="T_d5ece_row9_col3" class="data row9 col3" >8825</td>
#       <td id="T_d5ece_row9_col4" class="data row9 col4" >339.05</td>
#       <td id="T_d5ece_row9_col5" class="data row9 col5" >39.53</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d5ece_row10_col0" class="data row10 col0" >CPIN.JK</td>
#       <td id="T_d5ece_row10_col1" class="data row10 col1" >4070</td>
#       <td id="T_d5ece_row10_col2" class="data row10 col2" >4070</td>
#       <td id="T_d5ece_row10_col3" class="data row10 col3" >4500</td>
#       <td id="T_d5ece_row10_col4" class="data row10 col4" >10.57</td>
#       <td id="T_d5ece_row10_col5" class="data row10 col5" >10.57</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d5ece_row11_col0" class="data row11 col0" >INDF.JK</td>
#       <td id="T_d5ece_row11_col1" class="data row11 col1" >5875</td>
#       <td id="T_d5ece_row11_col2" class="data row11 col2" >6600</td>
#       <td id="T_d5ece_row11_col3" class="data row11 col3" >8150</td>
#       <td id="T_d5ece_row11_col4" class="data row11 col4" >38.72</td>
#       <td id="T_d5ece_row11_col5" class="data row11 col5" >23.48</td>
#     </tr>
#     <tr>
#       <th id="T_d5ece_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d5ece_row12_col0" class="data row12 col0" >KLBF.JK</td>
#       <td id="T_d5ece_row12_col1" class="data row12 col1" >1025</td>
#       <td id="T_d5ece_row12_col2" class="data row12 col2" >1025</td>
#       <td id="T_d5ece_row12_col3" class="data row12 col3" >1375</td>
#       <td id="T_d5ece_row12_col4" class="data row12 col4" >34.15</td>
#       <td id="T_d5ece_row12_col5" class="data row12 col5" >34.15</td>
#     </tr>
#     <tr>
#       <th id=
