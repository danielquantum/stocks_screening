# %% [markdown]
# # MSCI Indonesian Stocks
# A Python script to monitor MSCI stocks performance by comparing the current market price against predefined base and support levels.

# %%
import yfinance as yf
import pandas as pd

# %%
def analyze_stocks(list_A, base_A, support_A):
    # Download last closing prices
    data = yf.download(list_A, period="1d", progress=False)
    closing = data['Close'].iloc[-1]

    # Ensure correct order of closing prices
    last_A = [closing[ticker] for ticker in list_A]

    # Create DataFrame
    stocks_A = pd.DataFrame({
        'Stock': list_A,
        'Base': base_A,
        'Support': support_A,
        'Last Price': last_A})
    
    stocks_A['Change from Base (%)'] = (stocks_A['Last Price'] - stocks_A['Base'])/stocks_A['Base']*100
    stocks_A['Change from Support (%)'] = (stocks_A['Last Price'] - stocks_A['Support'])/stocks_A['Support']*100

    # Styling function
    def color_change(val):
        color = 'green' if val > 0 else 'red'
        return f'color: {color}'

    # Return styled DataFrame
    styled_stocks_A = stocks_A.style \
        .map(color_change, subset=['Change from Base (%)', 'Change from Support (%)']) \
        .format({
            'Last Price': '{:.0f}',
            'Change from Base (%)': '{:.2f}',
            'Change from Support (%)': '{:.2f}'})
    return styled_stocks_A

# %%
def analyze_stocks_realtime(list_A, base_A, support_A):
    # Get realtime prices using .fast_info['lastPrice']
    last_A = []
    for ticker in list_A:
        try:
            stock = yf.Ticker(ticker)
            last_price = stock.fast_info['lastPrice']
        except Exception:
            last_price = None
        last_A.append(last_price)

    # Create DataFrame
    stocks_A = pd.DataFrame({
        'Stock': list_A,
        'Base': base_A,
        'Support': support_A,
        'Last': last_A})

    # Create DataFrame
    stocks_A = pd.DataFrame({
        'Stock': list_A,
        'Base': base_A,
        'Support': support_A,
        'Last Price': last_A})
    
    stocks_A['Change from Base (%)'] = (stocks_A['Last Price'] - stocks_A['Base'])/stocks_A['Base']*100
    stocks_A['Change from Support (%)'] = (stocks_A['Last Price'] - stocks_A['Support'])/stocks_A['Support']*100

    # Styling function
    def color_change(val):
        color = 'green' if val > 0 else 'red'
        return f'color: {color}'

    # Return styled DataFrame
    styled_stocks_A = stocks_A.style \
        .map(color_change, subset=['Change from Base (%)', 'Change from Support (%)']) \
        .format({
            'Last Price': '{:.0f}',
            'Change from Base (%)': '{:.2f}',
            'Change from Support (%)': '{:.2f}'})
    return styled_stocks_A

# %% [markdown]
# # My Stocks

# %%
# My Stocks
list_A = ["BBCA.JK", "BBRI.JK", "BMRI.JK", "BBNI.JK", "TLKM.JK", "ASII.JK", "PTBA.JK"]
base_A = [7400, 3360, 4350, 3670, 2310, 4430, 2300]
support_A = [8275, 3650, 4510, 3950, 2630, 4690, 2390]

stocks_A = analyze_stocks(list_A, base_A, support_A)
stocks_A
# Out:
# /var/folders/h9/3814k15d6g9gqm3g5762t5g40000gn/T/ipykernel_4116/49570061.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(list_A, period="1d", progress=False)
# <style type="text/css">
# #T_92382_row0_col4, #T_92382_row0_col5, #T_92382_row1_col4, #T_92382_row1_col5, #T_92382_row2_col4, #T_92382_row2_col5, #T_92382_row3_col4, #T_92382_row3_col5, #T_92382_row4_col4, #T_92382_row4_col5, #T_92382_row5_col4, #T_92382_row5_col5, #T_92382_row6_col4, #T_92382_row6_col5 {
#   color: green;
# }
# </style>
# <table id="T_92382">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_92382_level0_col0" class="col_heading level0 col0" >Stock</th>
#       <th id="T_92382_level0_col1" class="col_heading level0 col1" >Base</th>
#       <th id="T_92382_level0_col2" class="col_heading level0 col2" >Support</th>
#       <th id="T_92382_level0_col3" class="col_heading level0 col3" >Last Price</th>
#       <th id="T_92382_level0_col4" class="col_heading level0 col4" >Change from Base (%)</th>
#       <th id="T_92382_level0_col5" class="col_heading level0 col5" >Change from Support (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_92382_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_92382_row0_col0" class="data row0 col0" >BBCA.JK</td>
#       <td id="T_92382_row0_col1" class="data row0 col1" >7400</td>
#       <td id="T_92382_row0_col2" class="data row0 col2" >8275</td>
#       <td id="T_92382_row0_col3" class="data row0 col3" >8550</td>
#       <td id="T_92382_row0_col4" class="data row0 col4" >15.54</td>
#       <td id="T_92382_row0_col5" class="data row0 col5" >3.32</td>
#     </tr>
#     <tr>
#       <th id="T_92382_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_92382_row1_col0" class="data row1 col0" >BBRI.JK</td>
#       <td id="T_92382_row1_col1" class="data row1 col1" >3360</td>
#       <td id="T_92382_row1_col2" class="data row1 col2" >3650</td>
#       <td id="T_92382_row1_col3" class="data row1 col3" >3810</td>
#       <td id="T_92382_row1_col4" class="data row1 col4" >13.39</td>
#       <td id="T_92382_row1_col5" class="data row1 col5" >4.38</td>
#     </tr>
#     <tr>
#       <th id="T_92382_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_92382_row2_col0" class="data row2 col0" >BMRI.JK</td>
#       <td id="T_92382_row2_col1" class="data row2 col1" >4350</td>
#       <td id="T_92382_row2_col2" class="data row2 col2" >4510</td>
#       <td id="T_92382_row2_col3" class="data row2 col3" >4720</td>
#       <td id="T_92382_row2_col4" class="data row2 col4" >8.51</td>
#       <td id="T_92382_row2_col5" class="data row2 col5" >4.66</td>
#     </tr>
#     <tr>
#       <th id="T_92382_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_92382_row3_col0" class="data row3 col0" >BBNI.JK</td>
#       <td id="T_92382_row3_col1" class="data row3 col1" >3670</td>
#       <td id="T_92382_row3_col2" class="data row3 col2" >3950</td>
#       <td id="T_92382_row3_col3" class="data row3 col3" >4200</td>
#       <td id="T_92382_row3_col4" class="data row3 col4" >14.44</td>
#       <td id="T_92382_row3_col5" class="data row3 col5" >6.33</td>
#     </tr>
#     <tr>
#       <th id="T_92382_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_92382_row4_col0" class="data row4 col0" >TLKM.JK</td>
#       <td id="T_92382_row4_col1" class="data row4 col1" >2310</td>
#       <td id="T_92382_row4_col2" class="data row4 col2" >2630</td>
#       <td id="T_92382_row4_col3" class="data row4 col3" >2990</td>
#       <td id="T_92382_row4_col4" class="data row4 col4" >29.44</td>
#       <td id="T_92382_row4_col5" class="data row4 col5" >13.69</td>
#     </tr>
#     <tr>
#       <th id="T_92382_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_92382_row5_col0" class="data row5 col0" >ASII.JK</td>
#       <td id="T_92382_row5_col1" class="data row5 col1" >4430</td>
#       <td id="T_92382_row5_col2" class="data row5 col2" >4690</td>
#       <td id="T_92382_row5_col3" class="data row5 col3" >4900</td>
#       <td id="T_92382_row5_col4" class="data row5 col4" >10.61</td>
#       <td id="T_92382_row5_col5" class="data row5 col5" >4.48</td>
#     </tr>
#     <tr>
#       <th id="T_92382_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_92382_row6_col0" class="data row6 col0" >PTBA.JK</td>
#       <td id="T_92382_row6_col1" class="data row6 col1" >2300</td>
#       <td id="T_92382_row6_col2" class="data row6 col2" >2390</td>
#       <td id="T_92382_row6_col3" class="data row6 col3" >2410</td>
#       <td id="T_92382_row6_col4" class="data row6 col4" >4.78</td>
#       <td id="T_92382_row6_col5" class="data row6 col5" >0.84</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Trading
list_B = ["AADI.JK", "ADMR.JK", "ADRO.JK", "AKRA.JK", "ASRI.JK", "AVIA.JK", "BBTN.JK", "BNGA.JK", "BRIS.JK", "BSDE.JK", "CDIA.JK", "CMRY.JK", "DKHH.JK", "PGAS.JK", "PTRO.JK", "ROTI.JK", "SRTG.JK", "WIFI.JK"]
base_B = [5750, 700, 1615, 895, 97, 342, 770, 1590, 2040, 725, 1485, 4030, 54, 1445, 1875, 795, 1225, 370]
support_B = [6700, 920, 1735, 1155, 121, 420, 1080, 1660, 2410, 780, 1485, 4530, 61, 1530, 2540, 795, 1560, 1985]

stocks_B = analyze_stocks(list_B, base_B, support_B)
stocks_B
# Out:
# /var/folders/h9/3814k15d6g9gqm3g5762t5g40000gn/T/ipykernel_4116/49570061.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(list_A, period="1d", progress=False)
# <style type="text/css">
# #T_ae3ce_row0_col4, #T_ae3ce_row0_col5, #T_ae3ce_row1_col4, #T_ae3ce_row1_col5, #T_ae3ce_row2_col4, #T_ae3ce_row2_col5, #T_ae3ce_row3_col4, #T_ae3ce_row3_col5, #T_ae3ce_row4_col4, #T_ae3ce_row4_col5, #T_ae3ce_row5_col4, #T_ae3ce_row5_col5, #T_ae3ce_row6_col4, #T_ae3ce_row6_col5, #T_ae3ce_row7_col4, #T_ae3ce_row7_col5, #T_ae3ce_row8_col4, #T_ae3ce_row8_col5, #T_ae3ce_row9_col4, #T_ae3ce_row9_col5, #T_ae3ce_row10_col4, #T_ae3ce_row10_col5, #T_ae3ce_row11_col4, #T_ae3ce_row11_col5, #T_ae3ce_row12_col4, #T_ae3ce_row12_col5, #T_ae3ce_row13_col4, #T_ae3ce_row13_col5, #T_ae3ce_row14_col4, #T_ae3ce_row14_col5, #T_ae3ce_row15_col4, #T_ae3ce_row15_col5, #T_ae3ce_row16_col4, #T_ae3ce_row16_col5, #T_ae3ce_row17_col4, #T_ae3ce_row17_col5 {
#   color: green;
# }
# </style>
# <table id="T_ae3ce">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae3ce_level0_col0" class="col_heading level0 col0" >Stock</th>
#       <th id="T_ae3ce_level0_col1" class="col_heading level0 col1" >Base</th>
#       <th id="T_ae3ce_level0_col2" class="col_heading level0 col2" >Support</th>
#       <th id="T_ae3ce_level0_col3" class="col_heading level0 col3" >Last Price</th>
#       <th id="T_ae3ce_level0_col4" class="col_heading level0 col4" >Change from Base (%)</th>
#       <th id="T_ae3ce_level0_col5" class="col_heading level0 col5" >Change from Support (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae3ce_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae3ce_row0_col0" class="data row0 col0" >AADI.JK</td>
#       <td id="T_ae3ce_row0_col1" class="data row0 col1" >5750</td>
#       <td id="T_ae3ce_row0_col2" class="data row0 col2" >6700</td>
#       <td id="T_ae3ce_row0_col3" class="data row0 col3" >7200</td>
#       <td id="T_ae3ce_row0_col4" class="data row0 col4" >25.22</td>
#       <td id="T_ae3ce_row0_col5" class="data row0 col5" >7.46</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae3ce_row1_col0" class="data row1 col0" >ADMR.JK</td>
#       <td id="T_ae3ce_row1_col1" class="data row1 col1" >700</td>
#       <td id="T_ae3ce_row1_col2" class="data row1 col2" >920</td>
#       <td id="T_ae3ce_row1_col3" class="data row1 col3" >1110</td>
#       <td id="T_ae3ce_row1_col4" class="data row1 col4" >58.57</td>
#       <td id="T_ae3ce_row1_col5" class="data row1 col5" >20.65</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae3ce_row2_col0" class="data row2 col0" >ADRO.JK</td>
#       <td id="T_ae3ce_row2_col1" class="data row2 col1" >1615</td>
#       <td id="T_ae3ce_row2_col2" class="data row2 col2" >1735</td>
#       <td id="T_ae3ce_row2_col3" class="data row2 col3" >1810</td>
#       <td id="T_ae3ce_row2_col4" class="data row2 col4" >12.07</td>
#       <td id="T_ae3ce_row2_col5" class="data row2 col5" >4.32</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae3ce_row3_col0" class="data row3 col0" >AKRA.JK</td>
#       <td id="T_ae3ce_row3_col1" class="data row3 col1" >895</td>
#       <td id="T_ae3ce_row3_col2" class="data row3 col2" >1155</td>
#       <td id="T_ae3ce_row3_col3" class="data row3 col3" >1285</td>
#       <td id="T_ae3ce_row3_col4" class="data row3 col4" >43.58</td>
#       <td id="T_ae3ce_row3_col5" class="data row3 col5" >11.26</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae3ce_row4_col0" class="data row4 col0" >ASRI.JK</td>
#       <td id="T_ae3ce_row4_col1" class="data row4 col1" >97</td>
#       <td id="T_ae3ce_row4_col2" class="data row4 col2" >121</td>
#       <td id="T_ae3ce_row4_col3" class="data row4 col3" >165</td>
#       <td id="T_ae3ce_row4_col4" class="data row4 col4" >70.10</td>
#       <td id="T_ae3ce_row4_col5" class="data row4 col5" >36.36</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ae3ce_row5_col0" class="data row5 col0" >AVIA.JK</td>
#       <td id="T_ae3ce_row5_col1" class="data row5 col1" >342</td>
#       <td id="T_ae3ce_row5_col2" class="data row5 col2" >420</td>
#       <td id="T_ae3ce_row5_col3" class="data row5 col3" >428</td>
#       <td id="T_ae3ce_row5_col4" class="data row5 col4" >25.15</td>
#       <td id="T_ae3ce_row5_col5" class="data row5 col5" >1.90</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ae3ce_row6_col0" class="data row6 col0" >BBTN.JK</td>
#       <td id="T_ae3ce_row6_col1" class="data row6 col1" >770</td>
#       <td id="T_ae3ce_row6_col2" class="data row6 col2" >1080</td>
#       <td id="T_ae3ce_row6_col3" class="data row6 col3" >1205</td>
#       <td id="T_ae3ce_row6_col4" class="data row6 col4" >56.49</td>
#       <td id="T_ae3ce_row6_col5" class="data row6 col5" >11.57</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ae3ce_row7_col0" class="data row7 col0" >BNGA.JK</td>
#       <td id="T_ae3ce_row7_col1" class="data row7 col1" >1590</td>
#       <td id="T_ae3ce_row7_col2" class="data row7 col2" >1660</td>
#       <td id="T_ae3ce_row7_col3" class="data row7 col3" >1705</td>
#       <td id="T_ae3ce_row7_col4" class="data row7 col4" >7.23</td>
#       <td id="T_ae3ce_row7_col5" class="data row7 col5" >2.71</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ae3ce_row8_col0" class="data row8 col0" >BRIS.JK</td>
#       <td id="T_ae3ce_row8_col1" class="data row8 col1" >2040</td>
#       <td id="T_ae3ce_row8_col2" class="data row8 col2" >2410</td>
#       <td id="T_ae3ce_row8_col3" class="data row8 col3" >2730</td>
#       <td id="T_ae3ce_row8_col4" class="data row8 col4" >33.82</td>
#       <td id="T_ae3ce_row8_col5" class="data row8 col5" >13.28</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ae3ce_row9_col0" class="data row9 col0" >BSDE.JK</td>
#       <td id="T_ae3ce_row9_col1" class="data row9 col1" >725</td>
#       <td id="T_ae3ce_row9_col2" class="data row9 col2" >780</td>
#       <td id="T_ae3ce_row9_col3" class="data row9 col3" >880</td>
#       <td id="T_ae3ce_row9_col4" class="data row9 col4" >21.38</td>
#       <td id="T_ae3ce_row9_col5" class="data row9 col5" >12.82</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ae3ce_row10_col0" class="data row10 col0" >CDIA.JK</td>
#       <td id="T_ae3ce_row10_col1" class="data row10 col1" >1485</td>
#       <td id="T_ae3ce_row10_col2" class="data row10 col2" >1485</td>
#       <td id="T_ae3ce_row10_col3" class="data row10 col3" >1515</td>
#       <td id="T_ae3ce_row10_col4" class="data row10 col4" >2.02</td>
#       <td id="T_ae3ce_row10_col5" class="data row10 col5" >2.02</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ae3ce_row11_col0" class="data row11 col0" >CMRY.JK</td>
#       <td id="T_ae3ce_row11_col1" class="data row11 col1" >4030</td>
#       <td id="T_ae3ce_row11_col2" class="data row11 col2" >4530</td>
#       <td id="T_ae3ce_row11_col3" class="data row11 col3" >5000</td>
#       <td id="T_ae3ce_row11_col4" class="data row11 col4" >24.07</td>
#       <td id="T_ae3ce_row11_col5" class="data row11 col5" >10.38</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ae3ce_row12_col0" class="data row12 col0" >DKHH.JK</td>
#       <td id="T_ae3ce_row12_col1" class="data row12 col1" >54</td>
#       <td id="T_ae3ce_row12_col2" class="data row12 col2" >61</td>
#       <td id="T_ae3ce_row12_col3" class="data row12 col3" >78</td>
#       <td id="T_ae3ce_row12_col4" class="data row12 col4" >44.44</td>
#       <td id="T_ae3ce_row12_col5" class="data row12 col5" >27.87</td>
#     </tr>
#     <tr>
#       <th id="T_ae3ce_level0_row13" class="r

# %% [markdown]
# ## Watchlist

# %%
# Trading
list_C = ["PGEO.JK", "MDKA.JK", "INCO.JK",]
base_C = [730, 1035, 1845, ]
support_C = [1320, 1800, 3090]

stocks_C = analyze_stocks(list_C, base_C, support_C)
stocks_C
# Out:
# /var/folders/h9/3814k15d6g9gqm3g5762t5g40000gn/T/ipykernel_4116/49570061.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(list_A, period="1d", progress=False)
# <style type="text/css">
# #T_882e1_row0_col4, #T_882e1_row0_col5, #T_882e1_row1_col4, #T_882e1_row1_col5, #T_882e1_row2_col4, #T_882e1_row2_col5 {
#   color: green;
# }
# </style>
# <table id="T_882e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_882e1_level0_col0" class="col_heading level0 col0" >Stock</th>
#       <th id="T_882e1_level0_col1" class="col_heading level0 col1" >Base</th>
#       <th id="T_882e1_level0_col2" class="col_heading level0 col2" >Support</th>
#       <th id="T_882e1_level0_col3" class="col_heading level0 col3" >Last Price</th>
#       <th id="T_882e1_level0_col4" class="col_heading level0 col4" >Change from Base (%)</th>
#       <th id="T_882e1_level0_col5" class="col_heading level0 col5" >Change from Support (%)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_882e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_882e1_row0_col0" class="data row0 col0" >PGEO.JK</td>
#       <td id="T_882e1_row0_col1" class="data row0 col1" >730</td>
#       <td id="T_882e1_row0_col2" class="data row0 col2" >1320</td>
#       <td id="T_882e1_row0_col3" class="data row0 col3" >1565</td>
#       <td id="T_882e1_row0_col4" class="data row0 col4" >114.38</td>
#       <td id="T_882e1_row0_col5" class="data row0 col5" >18.56</td>
#     </tr>
#     <tr>
#       <th id="T_882e1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_882e1_row1_col0" class="data row1 col0" >MDKA.JK</td>
#       <td id="T_882e1_row1_col1" class="data row1 col1" >1035</td>
#       <td id="T_882e1_row1_col2" class="data row1 col2" >1800</td>
#       <td id="T_882e1_row1_col3" class="data row1 col3" >2390</td>
#       <td id="T_882e1_row1_col4" class="data row1 col4" >130.92</td>
#       <td id="T_882e1_row1_col5" class="data row1 col5" >32.78</td>
#     </tr>
#     <tr>
#       <th id="T_882e1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_882e1_row2_col0" class="data row2 col0" >INCO.JK</td>
#       <td id="T_882e1_row2_col1" class="data row2 col1" >1845</td>
#       <td id="T_882e1_row2_col2" class="data row2 col2" >3090</td>
#       <td id="T_882e1_row2_col3" class="data row2 col3" >3920</td>
#       <td id="T_882e1_row2_col4" class="data row2 col4" >112.47</td>
#       <td id="T_882e1_row2_col5" class="data row2 col5" >26.86</td>
#     </tr>
#   </tbody>
# </table>
